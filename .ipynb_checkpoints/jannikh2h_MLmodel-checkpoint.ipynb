# %%
import sklearn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(sklearn.__version__)
# Out:
# 1.5.1

# %%
jannik_data = pd.read_csv('jannikh2h.csv')

# %%
jannik_data.head(5)
# Out:
#    H2Hs                  Opponent  W  L    Win%  TB  TBW  TBL    TB%  \
# 0    12     Daniil Medvedev [RUS]  5  7   41.7%   8    5    3  62.5%
# 1    10      Carlos Alcaraz [ESP]  4  6   40.0%   8    3    5  37.5%
# 2     9  Stefanos Tsitsipas [GRE]  3  6   33.3%   2    0    2   0.0%
# 3     7      Alex De Minaur [AUS]  7  0  100.0%   2    1    1  50.0%
# 4     7      Novak Djokovic [SRB]  3  4   42.9%   4    1    3  25.0%
#
#    First Match  ...    DR    A%   DF%  1stIn   1st%   2nd%    SPW    RPW  \
# 0  17‑Feb‑2020  ...  0.93  7.0%  1.5%  62.1%  71.7%  50.5%  63.6%  34.0%
# 1   1‑Apr‑2019  ...  1.01  4.1%  3.9%  57.7%  67.8%  52.0%  61.1%  39.4%
# 2  13‑May‑2019  ...  1.06  5.2%  2.2%  63.4%  72.6%  52.5%  65.2%  36.8%
# 3   5‑Nov‑2019  ...  1.35  6.2%  2.7%  60.7%  75.4%  52.6%  66.5%  45.3%
# 4  12‑Apr‑2021  ...  0.87  8.7%  3.1%  60.1%  70.4%  53.0%  63.5%  31.8%
#
#   BPSvd% BPCnv%
# 0  58.8%  36.1%
# 1  68.4%  49.3%
# 2  56.4%  29.9%
# 3  79.5%  51.7%
# 4  64.8%  41.0%
#
# [5 rows x 22 columns]

# %%
jannik_data = jannik_data.sample(frac=1).reset_index(drop=True)

# %%
jannik_data.shape
# Out:
# (210, 22)

# %%
jannik_data = jannik_data.dropna()

# %%
jannik_data.shape
# Out:
# (88, 22)

# %%
jannik_data.describe()
# Out:
#             H2Hs          W          L         TB        TBW        TBL  \
# count  88.000000  88.000000  88.000000  88.000000  88.000000  88.000000
# mean    2.852273   2.011364   0.840909   1.659091   1.000000   0.659091
# std     2.168424   1.458186   1.380374   1.312069   0.946864   0.869487
# min     1.000000   0.000000   0.000000   1.000000   0.000000   0.000000
# 25%     1.000000   1.000000   0.000000   1.000000   0.000000   0.000000
# 50%     2.000000   2.000000   0.000000   1.000000   1.000000   0.500000
# 75%     4.000000   3.000000   1.000000   2.000000   1.000000   1.000000
# max    12.000000   7.000000   7.000000   8.000000   5.000000   5.000000
#
#               MS         DR
# count  88.000000  88.000000
# mean    2.784091   1.220000
# std     2.130506   0.269273
# min     1.000000   0.680000
# 25%     1.000000   1.047500
# 50%     2.000000   1.190000
# 75%     3.250000   1.352500
# max    12.000000   2.090000

# %%
for col in jannik_data.columns:
    print(jannik_data[col].dtype)
# Out:
# int64
# object
# int64
# int64
# float64
# int64
# int64
# int64
# float64
# object
# object
# float64
# float64
# object
# object
# object
# object
# object
# object
# object
# object
# object

# %%
for col in jannik_data.columns:
    if col not in ['H2Hs', 'Opponent', 'W', 'L', 'TB', 'TBW', 'TBL', 'First Match', 'Last Match', 'DR']:
        if jannik_data[col] is not (int or float):
            jannik_data[col] = jannik_data[col].astype('str')
            jannik_data[col] = jannik_data[col].str.rstrip('%').astype('float') / 100.0
        else:
            jannik_data[col] = jannik_data[col].astype('float')
#jannik_data['Win%'] = jannik_data['Win%'].str.rstrip('%').astype('float') / 100.0
#jannik_data['DR'] = jannik_data['DR'].astype('float')

# %%
jannik_data.head()
# Out:
#     H2Hs                     Opponent  W  L   Win%  TB  TBW  TBL      TB%  \
# 2     10         Carlos Alcaraz [ESP]  4  6  0.004   8    3    5  0.00375
# 6      2  Pierre Hugues Herbert [FRA]  2  0  0.010   1    0    1  0.00000
# 7      1          Zhizhen Zhang [CHN]  1  0  0.010   1    1    0  0.01000
# 9      2      Matteo Berrettini [ITA]  2  0  0.010   3    3    0  0.01000
# 14     2  Felix Auger Aliassime [CAN]  0  2  0.000   1    0    1  0.00000
#
#     First Match  ...    DR     A%    DF%  1stIn   1st%   2nd%    SPW    RPW  \
# 2    1‑Apr‑2019  ...  1.01  0.041  0.039  0.577  0.678  0.520  0.611  0.394
# 6   19‑Oct‑2020  ...  1.26  0.034  0.029  0.636  0.679  0.560  0.636  0.458
# 7   17‑Jun‑2024  ...  1.38  0.121  0.015  0.652  0.814  0.609  0.742  0.356
# 9    7‑Aug‑2023  ...  1.27  0.101  0.020  0.652  0.822  0.536  0.722  0.354
# 14   2‑May‑2022  ...  0.68  0.032  0.032  0.606  0.564  0.541  0.555  0.301
#
#     BPSvd%  BPCnv%
# 2    0.684   0.493
# 6    0.667   0.778
# 7    1.000   1.000
# 9    0.714   0.286
# 14   0.563   0.375
#
# [5 rows x 22 columns]

# %%
fig, ax = plt.subplots(figsize=(12,8))

plt.scatter(jannik_data['DR'], jannik_data['Win%'])
plt.ylabel('Win%')
plt.xlabel('Dominance R')
# Out:
# Text(0.5, 0, 'Dominance R')

# %%
jannik_data_nostring = jannik_data.drop(['Opponent', 'First Match', 'Last Match'], axis=1)
jannik_h2h_corr = jannik_data_nostring.corr()
jannik_h2h_corr
# Out:
#             H2Hs         W         L      Win%        TB       TBW       TBL  \
# H2Hs    1.000000  0.778461  0.748553 -0.131775  0.689093  0.464651  0.533850
# W       0.778461  1.000000  0.166512  0.374665  0.422590  0.491170  0.102814
# L       0.748553  0.166512  1.000000 -0.602789  0.636082  0.211061  0.730014
# Win%   -0.131775  0.374665 -0.602789  1.000000 -0.144780  0.238299 -0.477980
# TB      0.689093  0.422590  0.636082 -0.144780  1.000000  0.749413  0.692910
# TBW     0.464651  0.491170  0.211061  0.238299  0.749413  1.000000  0.041884
# TBL     0.533850  0.102814  0.730014 -0.477980  0.692910  0.041884  1.000000
# TB%    -0.084144  0.210802 -0.354866  0.576035 -0.050893  0.534786 -0.659175
# MS      0.993200  0.770369  0.746419 -0.138219  0.684723  0.461525  0.530660
# DR     -0.150002  0.213697 -0.461381  0.605145 -0.142171  0.100532 -0.324017
# A%     -0.052229  0.152758 -0.243416  0.333490 -0.004341  0.141063 -0.160167
# DF%    -0.037425 -0.078866  0.024521 -0.040434  0.002279 -0.047243  0.054886
# 1stIn   0.031026  0.015326  0.032550 -0.024502  0.100303  0.110743  0.030761
# 1st%   -0.040475  0.258083 -0.336213  0.536424 -0.010484  0.199042 -0.232575
# 2nd%   -0.072811  0.138314 -0.260489  0.321803 -0.026200  0.064844 -0.110151
# SPW    -0.068327  0.263612 -0.385806  0.575876 -0.009764  0.201817 -0.234511
# RPW    -0.136400  0.106329 -0.326593  0.387330 -0.228019 -0.061828 -0.276754
# BPSvd%  0.201316  0.395584 -0.101636  0.329844  0.144715  0.219908 -0.021100
# BPCnv% -0.081311  0.034495 -0.164171  0.286323 -0.098471 -0.037020 -0.108279
#
#              TB%        MS        DR        A%       DF%     1stIn      1st%  \
# H2Hs   -0.084144  0.993200 -0.150002 -0.052229 -0.037425  0.031026 -0.040475
# W       0.210802  0.770369  0.213697  0.152758 -0.078866  0.015326  0.258083
# L      -0.354866  0.746419 -0.461381 -0.243416  0.024521  0.032550 -0.336213
# Win%    0.576035 -0.138219  0.605145  0.333490 -0.040434 -0.024502  0.536424
# TB     -0.050893  0.684723 -0.142171 -0.004341  0.002279  0.100303 -0.010484
# TBW     0.534786  0.461525  0.100532  0.141063 -0.047243  0.110743  0.199042
# TBL    -0.659175  0.530660 -0.324017 -0.160167  0.054886  0.030761 -0.232575
# TB%     1.000000 -0.100110  0.336575  0.203421 -0.003566 -0.049599  0.341908
# MS     -0.100110  1.000000 -0.155277 -0.048579 -0.034516  0.046350 -0.043411
# DR      0.336575 -0.155277  1.000000  0.386844 -0.018795 -0.057895  0.726849
# A%      0.203421 -0.048579  0.386844  1.000000  0.022913  0.040069  0.614470
# DF%    -0.003566 -0.034516 -0.018795  0.022913  1.000000 -0.292793  0.052115
# 1stIn  -0.049599  0.046350 -0.057895  0.040069 -0.292793  1.000000 -0.053082
# 1st%    0.341908 -0.043411  0.726849  0.614470  0.052115 -0.053082  1.000000
# 2nd%    0.098226 -0.073565  0.555835  0.116623 -0.260740 -0.065074  0.234620
# SPW     0.312185 -0.067590  0.816233  0.541614 -0.132516  0.092707  0.872127
# RPW     0.207664 -0.145378  0.570601 -0.065101  0.091875 -0.233632  0.072204
# BPSvd%  0.152373  0.197388  0.191365  0.188956 -0.179664  0.047913  0.240149
# BPCnv%  0.136400 -0.069371  0.050404  0.002853  0.086815  0.134009 -0.001510
#
#             2nd%       SPW       RPW    BPSvd%    BPCnv%
# H2Hs   -0.072811 -0.068327 -0.136400  0.201316 -0.081311
# W       0.138314  0.263612  0.106329  0.395584  0.034495
# L      -0.260489 -0.385806 -0.326593 -0.101636 -0.164171
# Win%    0.321803  0.575876  0.387330  0.329844  0.286323
# TB     -0.026200 -0.009764 -0.228019  0.144715 -0.098471
# TBW     0.064844  0.201817 -0.061828  0.219908 -0.037020
# TBL    -0.110151 -0.234511 -0.276754 -0.021100 -0.108279
# TB%     0.098226  0.312185  0.207664  0.152373  0.136400
# MS     -0.073565 -0.067590 -0.145378  0.197388 -0.069371
# DR      0.555835  0.816233  0.570601  0.191365  0.050404
# A%      0.116623  0.541614 -0.065101  0.188956  0.002853
# DF%    -0.260740 -0.132516  0.091875 -0.179664  0.086815
# 1stIn  -0.065074  0.092707 -0.233632  0.047913  0.134009
# 1st%    0.234620  0.872127  0.072204  0.240149 -0.001510
# 2nd%    1.000000  0.645743  0.068926  0.217710  0.048705
# SPW     0.645743  1.000000  0.050558  0.312629  0.062815
# RPW     0.068926  0.050558  1.000000 -0.040544 -0.003038
# BPSvd%  0.217710  0.312629 -0.040544  1.000000  0.171541
# BPCnv%  0.048705  0.062815 -0.003038  0.171541  1.000000

# %%
fig, ax = plt.subplots(figsize=(12,10))
sns.heatmap(jannik_h2h_corr, annot=True)
# Out:
# <Axes: >
